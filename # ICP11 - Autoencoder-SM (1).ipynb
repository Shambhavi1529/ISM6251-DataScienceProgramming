# %% [markdown]
# ## ICP11 - Autoencoder | Testing the model on bottleneck neurons

# %% [markdown]
# ### Importing Library

# %%
import numpy as np

# %% [markdown]
# ### Load and normalize our data

# %%
from tensorflow.keras.datasets import mnist


# load MNIST data
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
print(train_images.shape)
print(test_images.shape)

# Flatten the images for a autoencoder input (28x28 is 784 -- therfore, input is 784 neurons)
train_images = np.reshape(train_images, (-1, 784))
test_images = np.reshape(test_images, (-1, 784))
print(train_images.shape)
print(test_images.shape)

# Normalize data - since it's grayscale, we can divide by 255 to get each pixel between 0 and 1
train_images = train_images.astype('float32') / 255
test_images = test_images.astype('float32') / 255
# Out:
# (60000, 28, 28)
# (10000, 28, 28)
# (60000, 784)
# (10000, 784)

# %%
from matplotlib import pyplot as plt

n = 10
plt.figure(figsize=(9, 2))
for i in range(n):
  ax = plt.subplot(1, n, i+1)
  plt.imshow(test_images[i].reshape(28, 28), cmap="gray")
  ax.axis('off')

plt.show()

# %% [markdown]
# ### Create an autoencoder model.

# %%
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

input_dim = 28*28
latent_vec_len = 6 # the bottleneck layer is set to six neurons

# Define the autoencoder architecture
# build the encoder
autoencoder = Sequential()
autoencoder.add(Input(shape=(input_dim,)))
autoencoder.add(Dense(500, activation='relu'))
autoencoder.add(Dense(300, activation='relu'))
autoencoder.add(Dense(100, activation='relu'))

# the bottleneck layer
autoencoder.add(Dense(latent_vec_len, activation='relu'))

# the decoder layer
autoencoder.add(Dense(100, activation='relu'))
autoencoder.add(Dense(300, activation='relu'))
autoencoder.add(Dense(500, activation='relu'))
autoencoder.add(Dense(input_dim, activation='sigmoid'))

# Compile the autoencoder model
autoencoder.compile(loss='binary_crossentropy', optimizer='adam')

# Get summary
autoencoder.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_8 (Dense)             (None, 500)               392500
#
#  dense_9 (Dense)             (None, 300)               150300
#
#  dense_10 (Dense)            (None, 100)               30100
#
#  dense_11 (Dense)            (None, 6)                 606
#
#  dense_12 (Dense)            (None, 100)               700
#
#  dense_13 (Dense)            (None, 300)               30300
#
#  dense_14 (Dense)            (None, 500)               150500
#
#  dense_15 (Dense)            (None, 784)               392784
#
# ...
# Total params: 1,147,790
# Trainable params: 1,147,790
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the autoencoder model.

# %%
from tensorflow.keras.callbacks import EarlyStopping # EarlyStopping during model training


# Train the autoencoder with MNIST data
early_stop = EarlyStopping(monitor='loss', patience=3, verbose=1)
history = autoencoder.fit(
    x=train_images, # For autoencoders, both the input and the target are the same
    y=train_images, 
    epochs=10, 
    batch_size=128,
    shuffle=True, 
    validation_data=(test_images, test_images),
    callbacks=[early_stop]
)
# Out:
# Epoch 1/10
# 469/469 [==============================] - 5s 10ms/step - loss: 0.2181 - val_loss: 0.1701
# Epoch 2/10
# 469/469 [==============================] - 5s 10ms/step - loss: 0.1623 - val_loss: 0.1518
# Epoch 3/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1463 - val_loss: 0.1391
# Epoch 4/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1362 - val_loss: 0.1338
# Epoch 5/10
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1319 - val_loss: 0.1309
# Epoch 6/10
# 469/469 [==============================] - 5s 11ms/step - loss: 0.1290 - val_loss: 0.1280
# Epoch 7/10
# 469/469 [==============================] - 5s 11ms/step - loss: 0.1269 - val_loss: 0.1262
# Epoch 8/10
# 469/469 [==============================] - 5s 10ms/step - loss: 0.1253 - val_loss: 0.1255
# Epoch 9/10
# 469/469 [==============================] - 5s 10ms/step - loss: 0.1238 - val_loss: 0.1239
# Epoch 10/10
# ...

# %%
# Plot training and validation loss scores
# against the number of epochs.
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.ylabel('Binary Cross Entropy Loss')
plt.xlabel('Epoch')
plt.title('Autoencoder Reconstruction Loss', pad=13)
plt.legend(loc='upper right')

# %% [markdown]
# ### Test the autoencoder model by reconstructing the test images and visually inspecting the results.

# %%
reconstructed_images = autoencoder.predict(test_images)

images = []
for i in range(100):
    images.append(test_images[i].reshape(28,28))
    images.append(reconstructed_images[i].reshape(28,28))
rows = 10
cols = 10
plt.figure(figsize=(10,10))
for i in range(rows*cols):
    plt.subplot(rows,cols,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    if (i%2 == 0):
        plt.imshow(images[i],cmap='gray')
    else:
        plt.imshow(images[i])
plt.show()
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# ### Save the autoencoder for later user.

# %%
autoencoder.save('Downloads/initially_trained_autoencoder.h5')

# %% [markdown]
# But what happens if we sent it something it has been trained on? Let’s try it out:

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image


####################################
# load a sample image
image = tf.keras.utils.load_img('Downloads/testimg02.png', target_size=(28, 28), color_mode = "grayscale")


####################################
# predict an image from this sample
input_arr = tf.keras.utils.img_to_array(image)
input_arr = input_arr/ 255 # normalize between 0 and 1
input_arr = input_arr.reshape(784)
input_arr = np.array([input_arr])  # Convert single image to a batch with one image in it

predictions = autoencoder.predict(input_arr)
print(predictions.shape)


#####################################
# display the two images side by side
# 
plt.subplot(1,2,1)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.imshow(image, cmap="gray")


plt.subplot(1,2,2)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.imshow(predictions[0].reshape(28,28), cmap="gray")


plt.show()
# Out:
# 1/1 [==============================] - 0s 12ms/step
# (1, 784)

# %% [markdown]
# ## Conclusion
#
# When the bottleneck of the autoencoder model was altered from 16 neurons to 6 neurons to investigate the model's performance with a smaller bottleneck layer, the model's loss values were increased. While comparing the bottleneck layer sizes 16 and 6, it is evident that the loss is more when bottleneck layer neurons are reduced. As per the observation, if bottleneck layer is set to 100 neurons, the model will produce the lowest loss values, indicating that it was the best-performing model. However, a larger number of neurons in the bottleneck layer would increase model complexity and computational resources.
# The loss when bottleneck layer nueron was set to 16 was 0.945 whic is smaller than loss when bottleneck layer nueuron is 6 i.e., 0.954
#
# Even though a smaller bottleneck layer may not capture all the vital information in the input data, the loss values for the 6-neuron model were still be relatively low. It is necessary to examine the reconstructed images to determine if there are any significant variations between models with different bottleneck layer sizes.
#
# To conclude, Starting with a moderate number of neurons and altering the size could help find a balance between model complexity and performance.
